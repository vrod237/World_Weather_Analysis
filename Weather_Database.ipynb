# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import pandas as pd
import time
from config import weather_api_key
from datetime import datetime
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 628

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f4293d8dd1b56f0d45abb2b3512f0105

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        try:
            city_rain = city_weather["rain"]["1h"]
        except:
            city_rain = 0
        pass
    
        try:
            city_snow = city_weather["snow"]["1h"]
        except:
            city_snow = 0
        pass
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Desription": city_weather_description,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow
                           })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 13 | majene
# Processing Record 2 of Set 13 | albany
# Processing Record 3 of Set 13 | port alfred
# Processing Record 4 of Set 13 | flic en flac
# Processing Record 5 of Set 13 | batsfjord
# Processing Record 6 of Set 13 | toguchin
# Processing Record 7 of Set 13 | ushuaia
# Processing Record 8 of Set 13 | sapouy
# Processing Record 9 of Set 13 | upata
# Processing Record 10 of Set 13 | tuktoyaktuk
# Processing Record 11 of Set 13 | busselton
# Processing Record 12 of Set 13 | nikolskoye
# Processing Record 13 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 13 | vaini
# Processing Record 15 of Set 13 | itarema
# Processing Record 16 of Set 13 | ambulu
# Processing Record 17 of Set 13 | sorong
# Processing Record 18 of Set 13 | iqaluit
# Processing Record 19 of Set 13 | fairbanks
# Processing Record 20 of Set 13 | pevek
# Processing Record 21 of Set 13 | quang ngai
# Processing Record 22 of Set 13 | qaanaaq
# Processing Record 23 of Set 13 | pampa
# Processing Record 24 of Set 13 | lashio
# Processing Record 25 of Set 13 | mar del plata
# Processing Record 26 of Set 13 | bereda
# Processing Record 27 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 13 | bluff
# Processing Record 29 of Set 13 | luderitz
# Processing Record 30 of Set 13 | solnechnyy
# Processing Record 31 of Set 13 | udachnyy
# Processing Record 32 of Set 13 | uruzgan
# Processing Record 33 of Set 13 | ponta do sol
# Processing Record 34 of Set 13 | barrow
# Processing Record 35 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 13 | kapaa
# Processing Record 37 of Set 13 | uzyn
# Processing Record 38 of Set 13 | linguere
# Processing Record 39 of Set 13 | beyneu
# Processing Record 40 of Set 13 | severo-kurilsk
# Processing Record 41 of Set 13 | tongren
# Processing Record 42 of Set 13 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 13 | avarua
# Processing Record 44 of Set 13 | peregu mare
# Processing Record 45 of Set 13 | carnarvon
# Processing Record 46 of Set 13 | los llanos de aridane
# Processing Record 47 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 13 | hokitika
# Processing Record 49 of Set 13 | itacare
# Processing Record 50 of Set 13 | hermanus
# Processing Record 1 of Set 14 | mackenzie
# Processing Record 2 of Set 14 | pizarro
# Processing Record 3 of Set 14 | arraial do cabo
# Processing Record 4 of Set 14 | ilulissat
# Processing Record 5 of Set 14 | rome
# Processing Record 6 of Set 14 | atuona
# Processing Record 7 of Set 14 | maneadero
# Processing Record 8 of Set 14 | dunedin
# Processing Record 9 of Set 14 | corumba
# Processing Record 10 of Set 14 | hobart
# Processing Record 11 of Set 14 | kaitangata
# Processing Record 12 of Set 14 | caucaia
# Processing Record 13 of Set 14 | diffa
# Processing Record 14 of Set 14 | bengkulu
# Processing Record 15 of Set 14 | yuksekova
# Processing Record 16 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 17 of Set 14 | butaritari
# Processing Record 18 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 14 | fortuna
# Processing Record 20 of Set 14 | contamana
# Processing Record 21 of Set 14 | ewa beach
# Processing Record 22 of Set 14 | muisne
# Processing Record 23 of Set 14 | torbay
# Processing Record 24 of Set 14 | palmas bellas
# Processing Record 25 of Set 14 | balabac
# Processing Record 26 of Set 14 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 14 | nemuro
# Processing Record 28 of Set 14 | provideniya
# Processing Record 29 of Set 14 | saskylakh
# Processing Record 30 of Set 14 | roma
# Processing Record 31 of Set 14 | bredasdorp
# Processing Record 32 of Set 14 | avera
# Processing Record 33 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 14 | puerto carreno
# Processing Record 35 of Set 14 | puerto ayora
# Processing Record 36 of Set 14 | novoanninskiy
# Processing Record 37 of Set 14 | darbhanga
# Processing Record 38 of Set 14 | anadyr
# Processing Record 39 of Set 14 | dikson
# Processing Record 40 of Set 14 | punta arenas
# Processing Record 41 of Set 14 | kharp
# Processing Record 42 of Set 14 | mae hong son
# Processing Record 43 of Set 14 | hilo
# Processing Record 44 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 14 | faanui
# Processing Record 46 of Set 14 | mandalgarh
# Processing Record 47 of Set 14 | xinyu
# Processing Record 48 of Set 14 | san juan
# Processing Record 49 of Set 14 | mto wa mbu
# Processing Record 50 of Set 14 | dekar
# Processing Record 1 of Set 15 | mayumba
# Processing Record 2 of Set 15 | paamiut
# Processing Record 3 of Set 15 | tumpat
# Processing Record 4 of Set 15 | omsukchan
# Processing Record 5 of Set 15 | santiago de cao
# Processing Record 6 of Set 15 | goderich
# Processing Record 7 of Set 15 | lagoa
# Processing Record 8 of Set 15 | baruun-urt
# Processing Record 9 of Set 15 | longyearbyen
# Processing Record 10 of Set 15 | norfolk
# Processing Record 11 of Set 15 | rikitea
# Processing Record 12 of Set 15 | castro
# Processing Record 13 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 15 | san cristobal
# Processing Record 15 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 15 | agadez
# Processing Record 17 of Set 15 | esperance
# Processing Record 18 of Set 15 | charters towers
# Processing Record 19 of Set 15 | lata
# Processing Record 20 of Set 15 | quatre cocos
# Processing Record 21 of Set 15 | terra santa
# Processing Record 22 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 23 of Set 15 | mataura
# Processing Record 24 of Set 15 | general roca
# Processing Record 25 of Set 15 | asau
# Processing Record 26 of Set 15 | iskateley
# Processing Record 27 of Set 15 | bambous virieux
# Processing Record 28 of Set 15 | pisco
# Processing Record 29 of Set 15 | kuzhener
# Processing Record 30 of Set 15 | east london
# Processing Record 31 of Set 15 | kruisfontein
# Processing Record 32 of Set 15 | victor harbor
# Processing Record 33 of Set 15 | little rock
# Processing Record 34 of Set 15 | tripoli
# Processing Record 35 of Set 15 | gizo
# Processing Record 36 of Set 15 | karratha
# Processing Record 37 of Set 15 | chernyshevskiy
# Processing Record 38 of Set 15 | asyut
# Processing Record 39 of Set 15 | turan
# Processing Record 40 of Set 15 | dalbandin
# Processing Record 41 of Set 15 | talnakh
# Processing Record 42 of Set 15 | sao joao da barra
# Processing Record 43 of Set 15 | bubaque
# Processing Record 44 of Set 15 | aklavik
# Processing Record 45 of Set 15 | alofi
# Processing Record 46 of Set 15 | tuatapere
# Processing Record 47 of Set 15 | de aar
# Processing Record 48 of Set 15 | leeuwarden
# Processing Record 49 of Set 15 | panaba
# Processing Record 50 of Set 15 | shakhtinsk
# Processing Record 1 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 16 | douglas
# Processing Record 4 of Set 16 | saint george
# Processing Record 5 of Set 16 | cabo san lucas
# Processing Record 6 of Set 16 | hasaki
# Processing Record 7 of Set 16 | new norfolk
# Processing Record 8 of Set 16 | jamestown
# Processing Record 9 of Set 16 | paradise valley
# Processing Record 10 of Set 16 | batagay-alyta
# Processing Record 11 of Set 16 | ygatimi
# Processing Record 12 of Set 16 | cape town
# Processing Record 13 of Set 16 | destin
# Processing Record 14 of Set 16 | lompoc
# Processing Record 15 of Set 16 | zharkent
# Processing Record 16 of Set 16 | nome
# Processing Record 17 of Set 16 | saint-philippe
# Processing Record 18 of Set 16 | college
# Processing Record 19 of Set 16 | walvis bay
# Processing Record 20 of Set 16 | makakilo city
# Processing Record 21 of Set 16 | chokurdakh
# Processing Record 22 of Set 16 | ambon
# Processing Record 23 of Set 16 | upernavik
# Processing Record 24 of Set 16 | fare
# Processing Record 25 of Set 16 | te anau
# Processing Record 26 of Set 16 | dali
# Processing Record 27 of Set 16 | tasiilaq
# Processing Record 28 of Set 16 | san policarpo
# Processing Record 29 of Set 16 | port hedland
# Processing Record 30 of Set 16 | dingle
# Processing Record 31 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 16 | camargo
# Processing Record 33 of Set 16 | cayenne
# Processing Record 34 of Set 16 | portland
# Processing Record 35 of Set 16 | waipawa
# Processing Record 36 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 16 | dunning
# Processing Record 38 of Set 16 | saldanha
# Processing Record 39 of Set 16 | lysva
# Processing Record 40 of Set 16 | fevralsk
# City not found. Skipping...
# Processing Record 41 of Set 16 | ostrovnoy
# Processing Record 42 of Set 16 | yellowknife
# Processing Record 43 of Set 16 | puerto narino
# Processing Record 44 of Set 16 | mayo
# Processing Record 45 of Set 16 | elat
# Processing Record 46 of Set 16 | ancud
# Processing Record 47 of Set 16 | yulara
# Processing Record 48 of Set 16 | olafsvik
# Processing Record 49 of Set 16 | erdenet
# Processing Record 50 of Set 16 | egvekinot
# Processing Record 1 of Set 17 | buala
# Processing Record 2 of Set 17 | bani walid
# Processing Record 3 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 17 | misratah
# Processing Record 5 of Set 17 | ust-kuyga
# Processing Record 6 of Set 17 | limoges
# Processing Record 7 of Set 17 | chuy
# Processing Record 8 of Set 17 | acapulco
# Processing Record 9 of Set 17 | souillac
# Processing Record 10 of Set 17 | chara
# Processing Record 11 of Set 17 | tongliao
# Processing Record 12 of Set 17 | mackay
# Processing Record 13 of Set 17 | zhanakorgan
# Processing Record 14 of Set 17 | nanortalik
# Processing Record 15 of Set 17 | smithers
# Processing Record 16 of Set 17 | ordu
# Processing Record 17 of Set 17 | paranhos
# Processing Record 18 of Set 17 | georgetown
# Processing Record 19 of Set 17 | zaraza
# Processing Record 20 of Set 17 | kumluca
# Processing Record 21 of Set 17 | jutai
# Processing Record 22 of Set 17 | lebu
# Processing Record 23 of Set 17 | tiznit
# Processing Record 24 of Set 17 | ahipara
# Processing Record 25 of Set 17 | thompson
# Processing Record 26 of Set 17 | yuzhne
# Processing Record 27 of Set 17 | payakumbuh
# Processing Record 28 of Set 17 | caravelas
# Processing Record 29 of Set 17 | mahebourg
# Processing Record 30 of Set 17 | alta floresta
# Processing Record 31 of Set 17 | cherskiy
# Processing Record 32 of Set 17 | port augusta
# Processing Record 33 of Set 17 | xuddur
# Processing Record 34 of Set 17 | rocha
# Processing Record 35 of Set 17 | matara
# Processing Record 36 of Set 17 | broken hill
# Processing Record 37 of Set 17 | bethel
# Processing Record 38 of Set 17 | ajdabiya
# Processing Record 39 of Set 17 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 17 | crotone
# Processing Record 41 of Set 17 | lasem
# Processing Record 42 of Set 17 | sioux lookout
# Processing Record 43 of Set 17 | fredericksburg
# Processing Record 44 of Set 17 | darhan
# Processing Record 45 of Set 17 | surt
# Processing Record 46 of Set 17 | isiro
# Processing Record 47 of Set 17 | ambilobe
# Processing Record 48 of Set 17 | carauari
# Processing Record 49 of Set 17 | inhambane
# Processing Record 50 of Set 17 | geraldton
# Processing Record 1 of Set 18 | puteyets
# Processing Record 2 of Set 18 | weymouth
# Processing Record 3 of Set 18 | ingham
# Processing Record 4 of Set 18 | sivas
# Processing Record 5 of Set 18 | yerofey pavlovich
# Processing Record 6 of Set 18 | teguldet
# Processing Record 7 of Set 18 | baoding
# Processing Record 8 of Set 18 | honiara
# Processing Record 9 of Set 18 | puli
# Processing Record 10 of Set 18 | sakakah
# Processing Record 11 of Set 18 | leningradskiy
# Processing Record 12 of Set 18 | khatanga
# Processing Record 13 of Set 18 | sheltozero
# Processing Record 14 of Set 18 | meulaboh
# Processing Record 15 of Set 18 | osorio
# Processing Record 16 of Set 18 | celestun
# Processing Record 17 of Set 18 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 18 | faya
# Processing Record 19 of Set 18 | mahon
# Processing Record 20 of Set 18 | hithadhoo
# Processing Record 21 of Set 18 | maues
# Processing Record 22 of Set 18 | bourail
# Processing Record 23 of Set 18 | warmbad
# Processing Record 24 of Set 18 | hay river
# Processing Record 25 of Set 18 | bardiyah
# Processing Record 26 of Set 18 | copiapo
# Processing Record 27 of Set 18 | yonibana
# Processing Record 28 of Set 18 | nioro
# Processing Record 29 of Set 18 | pangkalanbuun
# Processing Record 30 of Set 18 | kungurtug
# Processing Record 31 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 18 | san patricio
# Processing Record 33 of Set 18 | sao filipe
# Processing Record 34 of Set 18 | hue
# Processing Record 35 of Set 18 | mao
# Processing Record 36 of Set 18 | ixtapa
# Processing Record 37 of Set 18 | acuna
# City not found. Skipping...
# Processing Record 38 of Set 18 | ulaangom
# Processing Record 39 of Set 18 | bathsheba
# Processing Record 40 of Set 18 | anloga
# Processing Record 41 of Set 18 | tautira
# Processing Record 42 of Set 18 | palkaka
# City not found. Skipping...
# Processing Record 43 of Set 18 | opuwo
# Processing Record 44 of Set 18 | abilene
# Processing Record 45 of Set 18 | kodinsk
# Processing Record 46 of Set 18 | ribeira grande
# Processing Record 47 of Set 18 | lasa
# Processing Record 48 of Set 18 | rapid city
# Processing Record 49 of Set 18 | mnogovershinnyy
# Processing Record 50 of Set 18 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 19 | kouroussa
# Processing Record 2 of Set 19 | champerico
# Processing Record 3 of Set 19 | ponta delgada
# Processing Record 4 of Set 19 | port macquarie
# Processing Record 5 of Set 19 | cidreira
# Processing Record 6 of Set 19 | kloulklubed
# Processing Record 7 of Set 19 | linchuan
# City not found. Skipping...
# Processing Record 8 of Set 19 | coquimbo
# Processing Record 9 of Set 19 | filingue
# Processing Record 10 of Set 19 | esik
# Processing Record 11 of Set 19 | griffith
# Processing Record 12 of Set 19 | cap malheureux
# Processing Record 13 of Set 19 | sokoni
# Processing Record 14 of Set 19 | mecca
# Processing Record 15 of Set 19 | abu samrah
# Processing Record 16 of Set 19 | south lake tahoe
# Processing Record 17 of Set 19 | athabasca
# Processing Record 18 of Set 19 | port elizabeth
# Processing Record 19 of Set 19 | nacozari
# Processing Record 20 of Set 19 | santa marta
# Processing Record 21 of Set 19 | lorengau
# Processing Record 22 of Set 19 | wanaka
# Processing Record 23 of Set 19 | xichang
# Processing Record 24 of Set 19 | kavaratti
# Processing Record 25 of Set 19 | saint anthony
# Processing Record 26 of Set 19 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 19 | westport
# Processing Record 28 of Set 19 | sobreira
# Processing Record 29 of Set 19 | victoria
# Processing Record 30 of Set 19 | leshukonskoye
# Processing Record 31 of Set 19 | kitimat
# Processing Record 32 of Set 19 | ayagoz
# Processing Record 33 of Set 19 | arroyo
# Processing Record 34 of Set 19 | shirgaon
# Processing Record 35 of Set 19 | gobabis
# Processing Record 36 of Set 19 | toropets
# Processing Record 37 of Set 19 | puerto el triunfo
# Processing Record 38 of Set 19 | norman wells
# Processing Record 39 of Set 19 | nao-me-toque
# City not found. Skipping...
# Processing Record 40 of Set 19 | mount gambier
# Processing Record 41 of Set 19 | nishihara
# Processing Record 42 of Set 19 | worland
# Processing Record 43 of Set 19 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 19 | saint pete beach
# Processing Record 45 of Set 19 | vitoria
# Processing Record 46 of Set 19 | clyde river
# Processing Record 47 of Set 19 | pemangkat
# Processing Record 48 of Set 19 | lucatan
# City not found. Skipping...
# Processing Record 49 of Set 19 | taybad
# Processing Record 50 of Set 19 | severomorsk
# Processing Record 1 of Set 20 | kodiak
# Processing Record 2 of Set 20 | simpang
# Processing Record 3 of Set 20 | mogok
# Processing Record 4 of Set 20 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 5 of Set 20 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 20 | palembang
# Processing Record 7 of Set 20 | bjala
# City not found. Skipping...
# Processing Record 8 of Set 20 | atar
# Processing Record 9 of Set 20 | piacabucu
# Processing Record 10 of Set 20 | mizan teferi
# Processing Record 11 of Set 20 | nizhniy tsasuchey
# Processing Record 12 of Set 20 | touros
# Processing Record 13 of Set 20 | bulolo
# Processing Record 14 of Set 20 | balakhta
# Processing Record 15 of Set 20 | barcelona
# Processing Record 16 of Set 20 | point pedro
# Processing Record 17 of Set 20 | jijiga
# Processing Record 18 of Set 20 | tapaua
# City not found. Skipping...
# Processing Record 19 of Set 20 | san quintin
# Processing Record 20 of Set 20 | ayan
# Processing Record 21 of Set 20 | kontagora
# Processing Record 22 of Set 20 | richards bay
# Processing Record 23 of Set 20 | pundaguitan
# Processing Record 24 of Set 20 | port hawkesbury
# Processing Record 25 of Set 20 | pala
# Processing Record 26 of Set 20 | sinop
# Processing Record 27 of Set 20 | vardo
# Processing Record 28 of Set 20 | antofagasta
# Processing Record 29 of Set 20 | villarrica
# Processing Record 30 of Set 20 | taitung
# Processing Record 31 of Set 20 | saint-pierre
# Processing Record 32 of Set 20 | tanah merah
# Processing Record 33 of Set 20 | kiama
# Processing Record 34 of Set 20 | radcliff
# Processing Record 35 of Set 20 | calama
# Processing Record 36 of Set 20 | pacific grove
# Processing Record 37 of Set 20 | grand-santi
# Processing Record 38 of Set 20 | riyadh
# Processing Record 39 of Set 20 | piney green
# Processing Record 40 of Set 20 | nago
# Processing Record 41 of Set 20 | qandala
# Processing Record 42 of Set 20 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 20 | tomatlan
# Processing Record 44 of Set 20 | chifeng
# Processing Record 45 of Set 20 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 20 | niteroi
# Processing Record 47 of Set 20 | husavik
# Processing Record 48 of Set 20 | jagalur
# Processing Record 49 of Set 20 | airai
# Processing Record 50 of Set 20 | nerja
# Processing Record 1 of Set 21 | hurricane
# Processing Record 2 of Set 21 | breyten
# Processing Record 3 of Set 21 | port blair
# Processing Record 4 of Set 21 | hohhot
# Processing Record 5 of Set 21 | tahe
# Processing Record 6 of Set 21 | komsomolskiy
# Processing Record 7 of Set 21 | daru
# Processing Record 8 of Set 21 | sibiti
# Processing Record 9 of Set 21 | cervo
# Processing Record 10 of Set 21 | muana
# Processing Record 11 of Set 21 | lisakovsk
# Processing Record 12 of Set 21 | burnie
# Processing Record 13 of Set 21 | gat
# Processing Record 14 of Set 21 | harsin
# Processing Record 15 of Set 21 | luwuk
# Processing Record 16 of Set 21 | kalabo
# Processing Record 17 of Set 21 | dutse
# Processing Record 18 of Set 21 | tsagveri
# Processing Record 19 of Set 21 | chau doc
# Processing Record 20 of Set 21 | wad rawah
# Processing Record 21 of Set 21 | parabel
# Processing Record 22 of Set 21 | pauini
# Processing Record 23 of Set 21 | grand gaube
# Processing Record 24 of Set 21 | kegayli
# City not found. Skipping...
# Processing Record 25 of Set 21 | finschhafen
# Processing Record 26 of Set 21 | sola
# Processing Record 27 of Set 21 | melfi
# Processing Record 28 of Set 21 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 21 | port lincoln
# Processing Record 30 of Set 21 | port moresby
# Processing Record 31 of Set 21 | la primavera
# Processing Record 32 of Set 21 | merke
# Processing Record 33 of Set 21 | nong ki
# Processing Record 34 of Set 21 | namatanai
# Processing Record 35 of Set 21 | gurupi
# Processing Record 36 of Set 21 | batemans bay
# Processing Record 37 of Set 21 | verkhnyaya tishanka
# Processing Record 38 of Set 21 | huarmey
# Processing Record 39 of Set 21 | kalengwa
# Processing Record 40 of Set 21 | marsa matruh
# Processing Record 41 of Set 21 | moerai
# Processing Record 42 of Set 21 | mount darwin
# Processing Record 43 of Set 21 | dargaville
# Processing Record 44 of Set 21 | narsaq
# Processing Record 45 of Set 21 | umm lajj
# Processing Record 46 of Set 21 | sitka
# Processing Record 47 of Set 21 | logansport
# Processing Record 48 of Set 21 | gunjur
# Processing Record 49 of Set 21 | nazarovo
# Processing Record 50 of Set 21 | estevan
# Processing Record 1 of Set 22 | crato
# Processing Record 2 of Set 22 | mananjary
# Processing Record 3 of Set 22 | ambanja
# Processing Record 4 of Set 22 | planeta rica
# Processing Record 5 of Set 22 | el dorado
# Processing Record 6 of Set 22 | mehamn
# Processing Record 7 of Set 22 | khorixas
# Processing Record 8 of Set 22 | moctezuma
# Processing Record 9 of Set 22 | hamilton
# Processing Record 10 of Set 22 | mwingi
# Processing Record 11 of Set 22 | leninskoye
# Processing Record 12 of Set 22 | roald
# Processing Record 13 of Set 22 | yar-sale
# Processing Record 14 of Set 22 | bandarbeyla
# Processing Record 15 of Set 22 | hervey bay
# Processing Record 16 of Set 22 | ust-koksa
# Processing Record 17 of Set 22 | celano
# Processing Record 18 of Set 22 | natal
# Processing Record 19 of Set 22 | vezirkopru
# Processing Record 20 of Set 22 | arlit
# Processing Record 21 of Set 22 | euclides da cunha
# Processing Record 22 of Set 22 | slave lake
# Processing Record 23 of Set 22 | comodoro rivadavia
# Processing Record 24 of Set 22 | vila velha
# Processing Record 25 of Set 22 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 22 | takoradi
# Processing Record 27 of Set 22 | mahibadhoo
# Processing Record 28 of Set 22 | rehau
# Processing Record 29 of Set 22 | vostok
# Processing Record 30 of Set 22 | moletai
# Processing Record 31 of Set 22 | berezovyy
# Processing Record 32 of Set 22 | codrington
# Processing Record 33 of Set 22 | hazorasp
# Processing Record 34 of Set 22 | namibe
# Processing Record 35 of Set 22 | lembang
# Processing Record 36 of Set 22 | galiwinku
# City not found. Skipping...
# Processing Record 37 of Set 22 | chateaudun
# Processing Record 38 of Set 22 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 22 | sur
# Processing Record 40 of Set 22 | vanavara
# Processing Record 41 of Set 22 | abrau-dyurso
# Processing Record 42 of Set 22 | beloha
# Processing Record 43 of Set 22 | manzhouli
# Processing Record 44 of Set 22 | talara
# Processing Record 45 of Set 22 | grand island
# Processing Record 46 of Set 22 | pangody
# Processing Record 47 of Set 22 | igarka
# Processing Record 48 of Set 22 | nkhotakota
# Processing Record 49 of Set 22 | minbu
# Processing Record 50 of Set 22 | tilichiki
# Processing Record 1 of Set 23 | cururupu
# Processing Record 2 of Set 23 | atambua
# Processing Record 3 of Set 23 | sibolga
# Processing Record 4 of Set 23 | mullaitivu
# City not found. Skipping...
# Processing Record 5 of Set 23 | amahai
# Processing Record 6 of Set 23 | markova
# Processing Record 7 of Set 23 | bonthe
# Processing Record 8 of Set 23 | kaeo
# Processing Record 9 of Set 23 | tsalka
# Processing Record 10 of Set 23 | constitucion
# Processing Record 11 of Set 23 | grindavik
# Processing Record 12 of Set 23 | hirara
# Processing Record 13 of Set 23 | aransas pass
# Processing Record 14 of Set 23 | quijingue
# Processing Record 15 of Set 23 | rio grande
# Processing Record 16 of Set 23 | sosnovo-ozerskoye
# Processing Record 17 of Set 23 | saint-francois
# Processing Record 18 of Set 23 | kavieng
# Processing Record 19 of Set 23 | itapora
# Processing Record 20 of Set 23 | yenagoa
# Processing Record 21 of Set 23 | karpogory
# Processing Record 22 of Set 23 | saint-junien
# Processing Record 23 of Set 23 | gandajika
# Processing Record 24 of Set 23 | aksarka
# Processing Record 25 of Set 23 | chapais
# Processing Record 26 of Set 23 | safaga
# Processing Record 27 of Set 23 | noumea
# Processing Record 28 of Set 23 | arica
# Processing Record 29 of Set 23 | marzuq
# Processing Record 30 of Set 23 | weiser
# Processing Record 31 of Set 23 | ilinskiy
# Processing Record 32 of Set 23 | solovetskiy
# City not found. Skipping...
# Processing Record 33 of Set 23 | north bend
# Processing Record 34 of Set 23 | pacasmayo
# Processing Record 35 of Set 23 | tsentralnyy
# City not found. Skipping...
# Processing Record 36 of Set 23 | baker city
# Processing Record 37 of Set 23 | tarakan
# Processing Record 38 of Set 23 | maceio
# Processing Record 39 of Set 23 | baykit
# Processing Record 40 of Set 23 | tiksi
# Processing Record 41 of Set 23 | sembe
# Processing Record 42 of Set 23 | santander
# Processing Record 43 of Set 23 | santa rosa
# Processing Record 44 of Set 23 | los alamos
# Processing Record 45 of Set 23 | port-gentil
# Processing Record 46 of Set 23 | lagos
# Processing Record 47 of Set 23 | bad langensalza
# Processing Record 48 of Set 23 | deputatskiy
# Processing Record 49 of Set 23 | lincoln
# Processing Record 50 of Set 23 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 1 of Set 24 | nhulunbuy
# Processing Record 2 of Set 24 | logrono
# Processing Record 3 of Set 24 | vestmannaeyjar
# Processing Record 4 of Set 24 | tres arroyos
# Processing Record 5 of Set 24 | toamasina
# Processing Record 6 of Set 24 | macomer
# Processing Record 7 of Set 24 | vila
# Processing Record 8 of Set 24 | labuhan
# Processing Record 9 of Set 24 | tazovskiy
# Processing Record 10 of Set 24 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 24 | yarada
# Processing Record 12 of Set 24 | la verne
# Processing Record 13 of Set 24 | kediri
# Processing Record 14 of Set 24 | wonthaggi
# Processing Record 15 of Set 24 | yelets
# Processing Record 16 of Set 24 | khekra
# Processing Record 17 of Set 24 | san jose
# Processing Record 18 of Set 24 | grants
# Processing Record 19 of Set 24 | sung noen
# Processing Record 20 of Set 24 | chenzhou
# Processing Record 21 of Set 24 | cheremukhovo
# Processing Record 22 of Set 24 | tyrma
# Processing Record 23 of Set 24 | ko samui
# Processing Record 24 of Set 24 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 24 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 24 | wenling
# Processing Record 27 of Set 24 | sumbawa
# City not found. Skipping...
# Processing Record 28 of Set 24 | changji
# Processing Record 29 of Set 24 | tezu
# Processing Record 30 of Set 24 | molina
# Processing Record 31 of Set 24 | male
# Processing Record 32 of Set 24 | sunamganj
# City not found. Skipping...
# Processing Record 33 of Set 24 | mosquera
# Processing Record 34 of Set 24 | road town
# Processing Record 35 of Set 24 | bontang
# Processing Record 36 of Set 24 | trairi
# Processing Record 37 of Set 24 | vengerovo
# Processing Record 38 of Set 24 | boddam
# Processing Record 39 of Set 24 | kihei
# Processing Record 40 of Set 24 | bayir
# Processing Record 41 of Set 24 | zhuhai
# Processing Record 42 of Set 24 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 24 | kandrian
# Processing Record 44 of Set 24 | coahuayana
# Processing Record 45 of Set 24 | akdepe
# Processing Record 46 of Set 24 | aden
# Processing Record 47 of Set 24 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 24 | voh
# Processing Record 49 of Set 24 | henties bay
# Processing Record 50 of Set 24 | malwan
# City not found. Skipping...
# Processing Record 1 of Set 25 | horta
# Processing Record 2 of Set 25 | mora
# Processing Record 3 of Set 25 | tecoanapa
# Processing Record 4 of Set 25 | maralal
# Processing Record 5 of Set 25 | muros
# Processing Record 6 of Set 25 | kasongo-lunda
# Processing Record 7 of Set 25 | hami
# Processing Record 8 of Set 25 | kaniama
# Processing Record 9 of Set 25 | acarau
# Processing Record 10 of Set 25 | alotau
# City not found. Skipping...
# Processing Record 11 of Set 25 | ruidoso
# Processing Record 12 of Set 25 | thinadhoo
# Processing Record 13 of Set 25 | gravelbourg
# Processing Record 14 of Set 25 | praia da vitoria
# Processing Record 15 of Set 25 | cajamarca
# Processing Record 16 of Set 25 | salinopolis
# Processing Record 17 of Set 25 | suntar
# Processing Record 18 of Set 25 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 25 | ilebo
# Processing Record 20 of Set 25 | marawi
# Processing Record 21 of Set 25 | ayacucho
# Processing Record 22 of Set 25 | listvyagi
# Processing Record 23 of Set 25 | masuda
# Processing Record 24 of Set 25 | jurm
# Processing Record 25 of Set 25 | nizhniy ingash
# Processing Record 26 of Set 25 | wangqing
# Processing Record 27 of Set 25 | coolum beach
# Processing Record 28 of Set 25 | letlhakane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Majene      ID  -3.54  118.97     78.19        86         100
# 1        Albany      US  42.60  -73.97     84.00        76          75
# 2   Port Alfred      ZA -33.59   26.89     57.96        64          94
# 3  Flic En Flac      MU -20.27   57.36     72.00        68          75
# 4     Batsfjord      NO  70.63   29.72     53.60        66          75
# 5      Toguchin      RU  55.24   84.39     61.47        82           6
# 6       Ushuaia      AR -54.80  -68.30     30.20        80          75
# 7        Sapouy      BF  11.55   -1.77     84.40        64         100
# 8         Upata      VE   8.01  -62.40     81.00        84          99
# 9   Tuktoyaktuk      CA  69.45 -133.04     37.40        93          75
#
#    Wind Speed Current Desription  Rain (inches)  Snow (inches)
# 0       10.51    overcast clouds           0.00              0
# 1        7.78      broken clouds           0.00              0
# 2       28.32         light rain           0.36              0
# 3       12.75        shower rain           0.00              0
# 4       10.29      broken clouds           0.00              0
# 5        0.31          clear sky           0.00              0
# 6        3.36      broken clouds           0.00              0
# 7        7.02    overcast clouds           0.00              0
# 8        1.01         light rain           0.69              0
# 9        0.94               mist           0.00              0

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="")
