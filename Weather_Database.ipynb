# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import pandas as pd
import time
from config import weather_api_key
from datetime import datetime
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 637

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f4293d8dd1b56f0d45abb2b3512f0105

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        try:
            city_rain = city_weather["rain"]["1h"]
        except:
            city_rain = 0
        pass
    
        try:
            city_snow = city_weather["snow"]["1h"]
        except:
            city_snow = 0
        pass
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow
                           })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 13 | mandera
# Processing Record 2 of Set 13 | nome
# Processing Record 3 of Set 13 | vaini
# Processing Record 4 of Set 13 | punta arenas
# Processing Record 5 of Set 13 | maceio
# Processing Record 6 of Set 13 | arraial do cabo
# Processing Record 7 of Set 13 | novobirilyussy
# Processing Record 8 of Set 13 | sinop
# Processing Record 9 of Set 13 | kribi
# Processing Record 10 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 13 | codrington
# Processing Record 12 of Set 13 | busselton
# Processing Record 13 of Set 13 | la ronge
# Processing Record 14 of Set 13 | lebu
# Processing Record 15 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 13 | kapaa
# Processing Record 17 of Set 13 | fulitun
# City not found. Skipping...
# Processing Record 18 of Set 13 | rikitea
# Processing Record 19 of Set 13 | dikson
# Processing Record 20 of Set 13 | astara
# Processing Record 21 of Set 13 | lumeje
# Processing Record 22 of Set 13 | san jose
# Processing Record 23 of Set 13 | castro
# Processing Record 24 of Set 13 | mount pleasant
# Processing Record 25 of Set 13 | sao filipe
# Processing Record 26 of Set 13 | poli
# Processing Record 27 of Set 13 | bluff
# Processing Record 28 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 13 | albany
# Processing Record 30 of Set 13 | mananjary
# Processing Record 31 of Set 13 | pangnirtung
# Processing Record 32 of Set 13 | lahat
# Processing Record 33 of Set 13 | salalah
# Processing Record 34 of Set 13 | oga
# Processing Record 35 of Set 13 | victoria
# Processing Record 36 of Set 13 | ribeira grande
# Processing Record 37 of Set 13 | te anau
# Processing Record 38 of Set 13 | severo-kurilsk
# Processing Record 39 of Set 13 | nemuro
# Processing Record 40 of Set 13 | carnarvon
# Processing Record 41 of Set 13 | rongcheng
# Processing Record 42 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 13 | bredasdorp
# Processing Record 44 of Set 13 | gisborne
# Processing Record 45 of Set 13 | sitka
# Processing Record 46 of Set 13 | husavik
# Processing Record 47 of Set 13 | raudeberg
# Processing Record 48 of Set 13 | merano
# Processing Record 49 of Set 13 | pochutla
# Processing Record 50 of Set 13 | tual
# Processing Record 1 of Set 14 | nizhniy kuranakh
# Processing Record 2 of Set 14 | bridlington
# Processing Record 3 of Set 14 | mar del plata
# Processing Record 4 of Set 14 | chuy
# Processing Record 5 of Set 14 | barrow
# Processing Record 6 of Set 14 | bambous virieux
# Processing Record 7 of Set 14 | poum
# Processing Record 8 of Set 14 | faanui
# Processing Record 9 of Set 14 | coos bay
# Processing Record 10 of Set 14 | qasigiannguit
# Processing Record 11 of Set 14 | cherskiy
# Processing Record 12 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 14 | rorvik
# Processing Record 14 of Set 14 | port alfred
# Processing Record 15 of Set 14 | bengkulu
# Processing Record 16 of Set 14 | vardo
# Processing Record 17 of Set 14 | teknaf
# Processing Record 18 of Set 14 | new norfolk
# Processing Record 19 of Set 14 | provideniya
# Processing Record 20 of Set 14 | saint-philippe
# Processing Record 21 of Set 14 | manokwari
# Processing Record 22 of Set 14 | ushuaia
# Processing Record 23 of Set 14 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 14 | avarua
# Processing Record 25 of Set 14 | soledar
# Processing Record 26 of Set 14 | shingu
# Processing Record 27 of Set 14 | payo
# Processing Record 28 of Set 14 | cape town
# Processing Record 29 of Set 14 | bethel
# Processing Record 30 of Set 14 | wad rawah
# Processing Record 31 of Set 14 | banepa
# Processing Record 32 of Set 14 | hermanus
# Processing Record 33 of Set 14 | shubarkuduk
# Processing Record 34 of Set 14 | mataura
# Processing Record 35 of Set 14 | port lincoln
# Processing Record 36 of Set 14 | coihaique
# Processing Record 37 of Set 14 | narsaq
# Processing Record 38 of Set 14 | felidhoo
# City not found. Skipping...
# Processing Record 39 of Set 14 | kirakira
# Processing Record 40 of Set 14 | solnechnyy
# Processing Record 41 of Set 14 | xiaoshi
# Processing Record 42 of Set 14 | saldanha
# Processing Record 43 of Set 14 | atuona
# Processing Record 44 of Set 14 | ancud
# Processing Record 45 of Set 14 | beloha
# Processing Record 46 of Set 14 | hilo
# Processing Record 47 of Set 14 | klaksvik
# Processing Record 48 of Set 14 | yar-sale
# Processing Record 49 of Set 14 | soyo
# Processing Record 50 of Set 14 | iqaluit
# Processing Record 1 of Set 15 | minas
# Processing Record 2 of Set 15 | kortkeros
# Processing Record 3 of Set 15 | hamilton
# Processing Record 4 of Set 15 | port hawkesbury
# Processing Record 5 of Set 15 | vanavara
# Processing Record 6 of Set 15 | sangar
# Processing Record 7 of Set 15 | pleshanovo
# Processing Record 8 of Set 15 | pineville
# Processing Record 9 of Set 15 | phalaborwa
# Processing Record 10 of Set 15 | comodoro rivadavia
# Processing Record 11 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 15 | chokurdakh
# Processing Record 13 of Set 15 | we
# City not found. Skipping...
# Processing Record 14 of Set 15 | kemijarvi
# Processing Record 15 of Set 15 | kouroussa
# Processing Record 16 of Set 15 | nao-me-toque
# City not found. Skipping...
# Processing Record 17 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 15 | cururupu
# Processing Record 19 of Set 15 | roma
# Processing Record 20 of Set 15 | aklavik
# Processing Record 21 of Set 15 | la roche-sur-yon
# Processing Record 22 of Set 15 | miram shah
# Processing Record 23 of Set 15 | san cristobal
# Processing Record 24 of Set 15 | byron bay
# Processing Record 25 of Set 15 | kavieng
# Processing Record 26 of Set 15 | nevers
# Processing Record 27 of Set 15 | kaitangata
# Processing Record 28 of Set 15 | vyshkov
# Processing Record 29 of Set 15 | saint george
# Processing Record 30 of Set 15 | manta
# Processing Record 31 of Set 15 | galle
# Processing Record 32 of Set 15 | the valley
# Processing Record 33 of Set 15 | dom pedrito
# Processing Record 34 of Set 15 | soto la marina
# Processing Record 35 of Set 15 | tuktoyaktuk
# Processing Record 36 of Set 15 | kloulklubed
# Processing Record 37 of Set 15 | khatanga
# Processing Record 38 of Set 15 | vestmannaeyjar
# Processing Record 39 of Set 15 | norman wells
# Processing Record 40 of Set 15 | puerto ayora
# Processing Record 41 of Set 15 | griffith
# Processing Record 42 of Set 15 | ferme-neuve
# Processing Record 43 of Set 15 | kodiak
# Processing Record 44 of Set 15 | safaga
# Processing Record 45 of Set 15 | olafsvik
# Processing Record 46 of Set 15 | sarkand
# Processing Record 47 of Set 15 | hithadhoo
# Processing Record 48 of Set 15 | qaanaaq
# Processing Record 49 of Set 15 | lompoc
# Processing Record 50 of Set 15 | toungoo
# City not found. Skipping...
# Processing Record 1 of Set 16 | phetchabun
# Processing Record 2 of Set 16 | sovetskiy
# Processing Record 3 of Set 16 | nanortalik
# Processing Record 4 of Set 16 | palmer
# Processing Record 5 of Set 16 | buala
# Processing Record 6 of Set 16 | ahuimanu
# Processing Record 7 of Set 16 | luganville
# Processing Record 8 of Set 16 | boulsa
# Processing Record 9 of Set 16 | karpuninskiy
# City not found. Skipping...
# Processing Record 10 of Set 16 | turukhansk
# Processing Record 11 of Set 16 | torbay
# Processing Record 12 of Set 16 | namtsy
# Processing Record 13 of Set 16 | marigot
# Processing Record 14 of Set 16 | yerbogachen
# Processing Record 15 of Set 16 | nikolskoye
# Processing Record 16 of Set 16 | kieta
# Processing Record 17 of Set 16 | paamiut
# Processing Record 18 of Set 16 | kailua
# Processing Record 19 of Set 16 | talnakh
# Processing Record 20 of Set 16 | ruwi
# Processing Record 21 of Set 16 | okhotsk
# Processing Record 22 of Set 16 | guane
# Processing Record 23 of Set 16 | longyearbyen
# Processing Record 24 of Set 16 | ginir
# Processing Record 25 of Set 16 | taksimo
# Processing Record 26 of Set 16 | jalu
# Processing Record 27 of Set 16 | balabac
# Processing Record 28 of Set 16 | lazareni
# Processing Record 29 of Set 16 | luwuk
# Processing Record 30 of Set 16 | butaritari
# Processing Record 31 of Set 16 | taltal
# Processing Record 32 of Set 16 | jamestown
# Processing Record 33 of Set 16 | luderitz
# Processing Record 34 of Set 16 | thinadhoo
# Processing Record 35 of Set 16 | ambodifototra
# City not found. Skipping...
# Processing Record 36 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 16 | saskylakh
# Processing Record 38 of Set 16 | cabo san lucas
# Processing Record 39 of Set 16 | tasiilaq
# Processing Record 40 of Set 16 | puerto escondido
# Processing Record 41 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 16 | beringovskiy
# Processing Record 43 of Set 16 | matay
# Processing Record 44 of Set 16 | yellowknife
# Processing Record 45 of Set 16 | ambulu
# Processing Record 46 of Set 16 | tigzirt
# Processing Record 47 of Set 16 | luanda
# Processing Record 48 of Set 16 | analipsis
# Processing Record 49 of Set 16 | san policarpo
# Processing Record 50 of Set 16 | hokitika
# Processing Record 1 of Set 17 | oistins
# Processing Record 2 of Set 17 | ponta do sol
# Processing Record 3 of Set 17 | olga
# Processing Record 4 of Set 17 | hay river
# Processing Record 5 of Set 17 | cockburn town
# Processing Record 6 of Set 17 | tucuman
# Processing Record 7 of Set 17 | warragul
# Processing Record 8 of Set 17 | esperance
# Processing Record 9 of Set 17 | dingle
# Processing Record 10 of Set 17 | sinnamary
# Processing Record 11 of Set 17 | upernavik
# Processing Record 12 of Set 17 | cidreira
# Processing Record 13 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 17 | hobart
# Processing Record 15 of Set 17 | mandurah
# Processing Record 16 of Set 17 | nalut
# Processing Record 17 of Set 17 | broken hill
# Processing Record 18 of Set 17 | wajima
# Processing Record 19 of Set 17 | pevek
# Processing Record 20 of Set 17 | mpika
# Processing Record 21 of Set 17 | port elizabeth
# Processing Record 22 of Set 17 | milingimbi
# City not found. Skipping...
# Processing Record 23 of Set 17 | zhaotong
# Processing Record 24 of Set 17 | bydgoszcz
# Processing Record 25 of Set 17 | lagoa
# Processing Record 26 of Set 17 | darnah
# Processing Record 27 of Set 17 | hami
# Processing Record 28 of Set 17 | jabiru
# City not found. Skipping...
# Processing Record 29 of Set 17 | dzhankoy
# Processing Record 30 of Set 17 | kutum
# Processing Record 31 of Set 17 | wahran
# City not found. Skipping...
# Processing Record 32 of Set 17 | north bend
# Processing Record 33 of Set 17 | haverfordwest
# Processing Record 34 of Set 17 | katsuura
# Processing Record 35 of Set 17 | lampazos de naranjo
# Processing Record 36 of Set 17 | lavrentiya
# Processing Record 37 of Set 17 | clyde river
# Processing Record 38 of Set 17 | mudbidri
# Processing Record 39 of Set 17 | trat
# Processing Record 40 of Set 17 | murdochville
# Processing Record 41 of Set 17 | muhororo
# Processing Record 42 of Set 17 | carnaiba
# Processing Record 43 of Set 17 | kayerkan
# Processing Record 44 of Set 17 | ahipara
# Processing Record 45 of Set 17 | taoudenni
# Processing Record 46 of Set 17 | san patricio
# Processing Record 47 of Set 17 | vinh
# Processing Record 48 of Set 17 | gushikawa
# Processing Record 49 of Set 17 | semey
# Processing Record 50 of Set 17 | general roca
# Processing Record 1 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 18 | pozo colorado
# Processing Record 3 of Set 18 | korem
# Processing Record 4 of Set 18 | saint-francois
# Processing Record 5 of Set 18 | airai
# Processing Record 6 of Set 18 | honiara
# Processing Record 7 of Set 18 | cayenne
# Processing Record 8 of Set 18 | pisco
# Processing Record 9 of Set 18 | ellisras
# Processing Record 10 of Set 18 | cozumel
# Processing Record 11 of Set 18 | cairns
# Processing Record 12 of Set 18 | itoman
# Processing Record 13 of Set 18 | leningradskiy
# Processing Record 14 of Set 18 | sursk
# Processing Record 15 of Set 18 | ulagan
# Processing Record 16 of Set 18 | kruisfontein
# Processing Record 17 of Set 18 | eureka
# Processing Record 18 of Set 18 | emerald
# Processing Record 19 of Set 18 | sorong
# Processing Record 20 of Set 18 | tynda
# Processing Record 21 of Set 18 | doba
# Processing Record 22 of Set 18 | kuching
# Processing Record 23 of Set 18 | puerto leguizamo
# Processing Record 24 of Set 18 | karratha
# Processing Record 25 of Set 18 | suntar
# Processing Record 26 of Set 18 | wewak
# Processing Record 27 of Set 18 | kuytun
# Processing Record 28 of Set 18 | ulladulla
# Processing Record 29 of Set 18 | tiksi
# Processing Record 30 of Set 18 | zyryanka
# Processing Record 31 of Set 18 | aksarka
# Processing Record 32 of Set 18 | gympie
# Processing Record 33 of Set 18 | winona
# Processing Record 34 of Set 18 | tsabong
# Processing Record 35 of Set 18 | inhambane
# Processing Record 36 of Set 18 | suluova
# Processing Record 37 of Set 18 | khandbari
# Processing Record 38 of Set 18 | camacha
# Processing Record 39 of Set 18 | araouane
# Processing Record 40 of Set 18 | jacareacanga
# Processing Record 41 of Set 18 | kachikau
# City not found. Skipping...
# Processing Record 42 of Set 18 | mount isa
# Processing Record 43 of Set 18 | ilulissat
# Processing Record 44 of Set 18 | hasaki
# Processing Record 45 of Set 18 | makakilo city
# Processing Record 46 of Set 18 | cocobeach
# Processing Record 47 of Set 18 | fort dodge
# Processing Record 48 of Set 18 | le pont-de-claix
# Processing Record 49 of Set 18 | agadez
# Processing Record 50 of Set 18 | ardmore
# Processing Record 1 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 19 | sibolga
# Processing Record 3 of Set 19 | kulunda
# Processing Record 4 of Set 19 | faya
# Processing Record 5 of Set 19 | muros
# Processing Record 6 of Set 19 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 19 | saint-joseph
# Processing Record 8 of Set 19 | guerrero negro
# Processing Record 9 of Set 19 | tilichiki
# Processing Record 10 of Set 19 | maniitsoq
# Processing Record 11 of Set 19 | college
# Processing Record 12 of Set 19 | roald
# Processing Record 13 of Set 19 | tuatapere
# Processing Record 14 of Set 19 | ijaki
# City not found. Skipping...
# Processing Record 15 of Set 19 | holland
# Processing Record 16 of Set 19 | alofi
# Processing Record 17 of Set 19 | lakota
# Processing Record 18 of Set 19 | bandarbeyla
# Processing Record 19 of Set 19 | brae
# Processing Record 20 of Set 19 | yialos
# City not found. Skipping...
# Processing Record 21 of Set 19 | thompson
# Processing Record 22 of Set 19 | tawang
# Processing Record 23 of Set 19 | kamogawa
# Processing Record 24 of Set 19 | ostrovnoy
# Processing Record 25 of Set 19 | buariki
# City not found. Skipping...
# Processing Record 26 of Set 19 | saucillo
# Processing Record 27 of Set 19 | chuguyevka
# Processing Record 28 of Set 19 | aykhal
# Processing Record 29 of Set 19 | cabedelo
# Processing Record 30 of Set 19 | orlik
# Processing Record 31 of Set 19 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 19 | cosala
# Processing Record 33 of Set 19 | missoula
# Processing Record 34 of Set 19 | lagdo
# Processing Record 35 of Set 19 | debre zeyit
# Processing Record 36 of Set 19 | yatou
# Processing Record 37 of Set 19 | notre-dame-du-lac
# Processing Record 38 of Set 19 | isla mujeres
# Processing Record 39 of Set 19 | east london
# Processing Record 40 of Set 19 | grand gaube
# Processing Record 41 of Set 19 | diamantino
# Processing Record 42 of Set 19 | nouakchott
# Processing Record 43 of Set 19 | khash
# Processing Record 44 of Set 19 | imeni poliny osipenko
# Processing Record 45 of Set 19 | gravdal
# Processing Record 46 of Set 19 | lydenburg
# Processing Record 47 of Set 19 | kozulka
# Processing Record 48 of Set 19 | turlock
# Processing Record 49 of Set 19 | nishihara
# Processing Record 50 of Set 19 | redmond
# Processing Record 1 of Set 20 | isilkul
# Processing Record 2 of Set 20 | waverley
# Processing Record 3 of Set 20 | piopio
# Processing Record 4 of Set 20 | constitucion
# Processing Record 5 of Set 20 | san quintin
# Processing Record 6 of Set 20 | mana
# Processing Record 7 of Set 20 | mehamn
# Processing Record 8 of Set 20 | namatanai
# Processing Record 9 of Set 20 | sola
# Processing Record 10 of Set 20 | agadir
# Processing Record 11 of Set 20 | lichinga
# Processing Record 12 of Set 20 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 20 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 20 | astana
# Processing Record 15 of Set 20 | dombarovskiy
# Processing Record 16 of Set 20 | imeni babushkina
# Processing Record 17 of Set 20 | vigrestad
# Processing Record 18 of Set 20 | namibe
# Processing Record 19 of Set 20 | batemans bay
# Processing Record 20 of Set 20 | tindwari
# Processing Record 21 of Set 20 | tamiahua
# Processing Record 22 of Set 20 | goundam
# Processing Record 23 of Set 20 | madingou
# Processing Record 24 of Set 20 | port arthur
# Processing Record 25 of Set 20 | innisfail
# Processing Record 26 of Set 20 | georgetown
# Processing Record 27 of Set 20 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 20 | rantepao
# Processing Record 29 of Set 20 | tabuk
# Processing Record 30 of Set 20 | varca
# Processing Record 31 of Set 20 | karamay
# City not found. Skipping...
# Processing Record 32 of Set 20 | ust-kut
# Processing Record 33 of Set 20 | atherton
# Processing Record 34 of Set 20 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 20 | miri
# Processing Record 36 of Set 20 | labutta
# City not found. Skipping...
# Processing Record 37 of Set 20 | itarema
# Processing Record 38 of Set 20 | mahon
# Processing Record 39 of Set 20 | takoradi
# Processing Record 40 of Set 20 | ibague
# Processing Record 41 of Set 20 | padang
# Processing Record 42 of Set 20 | acapulco
# Processing Record 43 of Set 20 | qurbus
# Processing Record 44 of Set 20 | skjervoy
# Processing Record 45 of Set 20 | arecibo
# Processing Record 46 of Set 20 | pokrovsk
# Processing Record 47 of Set 20 | portland
# Processing Record 48 of Set 20 | bhalwal
# Processing Record 49 of Set 20 | samarai
# Processing Record 50 of Set 20 | cartagena
# Processing Record 1 of Set 21 | bethanien
# Processing Record 2 of Set 21 | nelson bay
# Processing Record 3 of Set 21 | harper
# Processing Record 4 of Set 21 | sukumo
# Processing Record 5 of Set 21 | fredericksburg
# Processing Record 6 of Set 21 | yangcun
# Processing Record 7 of Set 21 | grootegast
# Processing Record 8 of Set 21 | boa vista
# Processing Record 9 of Set 21 | novopokrovka
# Processing Record 10 of Set 21 | morant bay
# Processing Record 11 of Set 21 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 21 | new glasgow
# Processing Record 13 of Set 21 | altamirano
# Processing Record 14 of Set 21 | aksha
# Processing Record 15 of Set 21 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 21 | chapais
# Processing Record 17 of Set 21 | afikpo
# Processing Record 18 of Set 21 | bilibino
# Processing Record 19 of Set 21 | kudahuvadhoo
# Processing Record 20 of Set 21 | goderich
# Processing Record 21 of Set 21 | lasa
# Processing Record 22 of Set 21 | port hedland
# Processing Record 23 of Set 21 | banda aceh
# Processing Record 24 of Set 21 | masterton
# Processing Record 25 of Set 21 | stargard szczecinski
# Processing Record 26 of Set 21 | mackay
# Processing Record 27 of Set 21 | palasa
# Processing Record 28 of Set 21 | vila franca do campo
# Processing Record 29 of Set 21 | mgandu
# Processing Record 30 of Set 21 | athmallik
# Processing Record 31 of Set 21 | juneau
# Processing Record 32 of Set 21 | rognan
# Processing Record 33 of Set 21 | korla
# Processing Record 34 of Set 21 | bako
# Processing Record 35 of Set 21 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 21 | havre-saint-pierre
# Processing Record 37 of Set 21 | fortuna
# Processing Record 38 of Set 21 | rio gallegos
# Processing Record 39 of Set 21 | vao
# Processing Record 40 of Set 21 | virginia beach
# Processing Record 41 of Set 21 | fairbanks
# Processing Record 42 of Set 21 | oksfjord
# Processing Record 43 of Set 21 | santa isabel
# Processing Record 44 of Set 21 | vitim
# Processing Record 45 of Set 21 | tanout
# Processing Record 46 of Set 21 | los llanos de aridane
# Processing Record 47 of Set 21 | ola
# Processing Record 48 of Set 21 | ponta delgada
# Processing Record 49 of Set 21 | zhigansk
# Processing Record 50 of Set 21 | mayo
# Processing Record 1 of Set 22 | namalenga
# Processing Record 2 of Set 22 | dauriya
# Processing Record 3 of Set 22 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 22 | feijo
# Processing Record 5 of Set 22 | heiligenhafen
# Processing Record 6 of Set 22 | jasper
# Processing Record 7 of Set 22 | komsomolskiy
# Processing Record 8 of Set 22 | sao joao da barra
# Processing Record 9 of Set 22 | irricana
# Processing Record 10 of Set 22 | hunza
# City not found. Skipping...
# Processing Record 11 of Set 22 | sabzevar
# Processing Record 12 of Set 22 | gambela
# Processing Record 13 of Set 22 | deer lake
# Processing Record 14 of Set 22 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 22 | caborca
# Processing Record 16 of Set 22 | lubumbashi
# Processing Record 17 of Set 22 | nakhon si thammarat
# Processing Record 18 of Set 22 | teya
# Processing Record 19 of Set 22 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 22 | bunia
# Processing Record 21 of Set 22 | gayeri
# Processing Record 22 of Set 22 | havoysund
# Processing Record 23 of Set 22 | alyangula
# Processing Record 24 of Set 22 | najran
# Processing Record 25 of Set 22 | banjar
# Processing Record 26 of Set 22 | uige
# Processing Record 27 of Set 22 | kavaratti
# Processing Record 28 of Set 22 | atar
# Processing Record 29 of Set 22 | adrar
# Processing Record 30 of Set 22 | kwinana
# Processing Record 31 of Set 22 | sidi ali
# Processing Record 32 of Set 22 | langxiang
# Processing Record 33 of Set 22 | karpathos
# Processing Record 34 of Set 22 | pedernales
# Processing Record 35 of Set 22 | diebougou
# Processing Record 36 of Set 22 | kokrajhar
# Processing Record 37 of Set 22 | chiang khong
# Processing Record 38 of Set 22 | oktyabrskiy
# Processing Record 39 of Set 22 | satkhira
# Processing Record 40 of Set 22 | progreso
# Processing Record 41 of Set 22 | ketchikan
# Processing Record 42 of Set 22 | waddan
# Processing Record 43 of Set 22 | mitsamiouli
# Processing Record 44 of Set 22 | millinocket
# Processing Record 45 of Set 22 | bikin
# Processing Record 46 of Set 22 | mikhaylovka
# Processing Record 47 of Set 22 | caravelas
# Processing Record 48 of Set 22 | leh
# Processing Record 49 of Set 22 | salinopolis
# Processing Record 50 of Set 22 | tautira
# Processing Record 1 of Set 23 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 23 | jieshi
# Processing Record 3 of Set 23 | deputatskiy
# Processing Record 4 of Set 23 | chunoyar
# Processing Record 5 of Set 23 | la peca
# Processing Record 6 of Set 23 | morros
# Processing Record 7 of Set 23 | aripuana
# Processing Record 8 of Set 23 | port hardy
# Processing Record 9 of Set 23 | nyimba
# Processing Record 10 of Set 23 | ambilobe
# Processing Record 11 of Set 23 | kayes
# Processing Record 12 of Set 23 | vostok
# Processing Record 13 of Set 23 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 23 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 23 | synya
# Processing Record 16 of Set 23 | olavarria
# Processing Record 17 of Set 23 | amapa
# Processing Record 18 of Set 23 | mahebourg
# Processing Record 19 of Set 23 | cravo norte
# Processing Record 20 of Set 23 | nenjiang
# Processing Record 21 of Set 23 | sao sebastiao
# Processing Record 22 of Set 23 | kalispell
# Processing Record 23 of Set 23 | chulym
# Processing Record 24 of Set 23 | pattao
# Processing Record 25 of Set 23 | lata
# Processing Record 26 of Set 23 | kalabo
# Processing Record 27 of Set 23 | folsom
# Processing Record 28 of Set 23 | darhan
# Processing Record 29 of Set 23 | dubovka
# Processing Record 30 of Set 23 | rocha
# Processing Record 31 of Set 23 | ascona
# Processing Record 32 of Set 23 | bakchar
# Processing Record 33 of Set 23 | orje
# Processing Record 34 of Set 23 | gra liyia
# Processing Record 35 of Set 23 | marsh harbour
# Processing Record 36 of Set 23 | sheksna
# Processing Record 37 of Set 23 | chengde
# Processing Record 38 of Set 23 | shieli
# Processing Record 39 of Set 23 | ewa beach
# Processing Record 40 of Set 23 | svetlogorsk
# Processing Record 41 of Set 23 | berlevag
# Processing Record 42 of Set 23 | megion
# Processing Record 43 of Set 23 | lalmohan
# Processing Record 44 of Set 23 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 23 | plettenberg bay
# Processing Record 46 of Set 23 | senador guiomard
# Processing Record 47 of Set 23 | zhangjiakou
# Processing Record 48 of Set 23 | necochea
# Processing Record 49 of Set 23 | somanda
# Processing Record 50 of Set 23 | stornoway
# Processing Record 1 of Set 24 | hofn
# Processing Record 2 of Set 24 | henties bay
# Processing Record 3 of Set 24 | inuvik
# Processing Record 4 of Set 24 | abu kamal
# Processing Record 5 of Set 24 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 24 | toora-khem
# Processing Record 7 of Set 24 | banjarmasin
# Processing Record 8 of Set 24 | hualmay
# Processing Record 9 of Set 24 | chettipalaiyam
# Processing Record 10 of Set 24 | balimo
# City not found. Skipping...
# Processing Record 11 of Set 24 | khakhea
# Processing Record 12 of Set 24 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 24 | magdeburg
# Processing Record 14 of Set 24 | paita
# Processing Record 15 of Set 24 | fare
# Processing Record 16 of Set 24 | maldonado
# Processing Record 17 of Set 24 | belyy yar
# Processing Record 18 of Set 24 | tura
# Processing Record 19 of Set 24 | esso
# Processing Record 20 of Set 24 | verkhoyansk
# Processing Record 21 of Set 24 | labuhan
# Processing Record 22 of Set 24 | broome
# Processing Record 23 of Set 24 | azare
# Processing Record 24 of Set 24 | srednekolymsk
# Processing Record 25 of Set 24 | khorixas
# Processing Record 26 of Set 24 | abnub
# Processing Record 27 of Set 24 | borgarnes
# Processing Record 28 of Set 24 | ust-nera
# Processing Record 29 of Set 24 | moba
# Processing Record 30 of Set 24 | port blair
# Processing Record 31 of Set 24 | rio tercero
# Processing Record 32 of Set 24 | kondinskoye
# Processing Record 33 of Set 24 | ulcinj
# Processing Record 34 of Set 24 | kang
# Processing Record 35 of Set 24 | chipata
# Processing Record 36 of Set 24 | souillac
# Processing Record 37 of Set 24 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 24 | talcahuano
# Processing Record 39 of Set 24 | presidencia roque saenz pena
# Processing Record 40 of Set 24 | geraldton
# Processing Record 41 of Set 24 | quelimane
# Processing Record 42 of Set 24 | karakendzha
# City not found. Skipping...
# Processing Record 43 of Set 24 | sept-iles
# Processing Record 44 of Set 24 | knysna
# Processing Record 45 of Set 24 | noshiro
# Processing Record 46 of Set 24 | guajara-mirim
# City not found. Skipping...
# Processing Record 47 of Set 24 | auki
# Processing Record 48 of Set 24 | dudinka
# Processing Record 49 of Set 24 | bajil
# Processing Record 50 of Set 24 | amahai
# Processing Record 1 of Set 25 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 25 | lufilufi
# Processing Record 3 of Set 25 | celestun
# Processing Record 4 of Set 25 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 25 | ust-kulom
# Processing Record 6 of Set 25 | knoxville
# Processing Record 7 of Set 25 | abu dhabi
# Processing Record 8 of Set 25 | englehart
# Processing Record 9 of Set 25 | ballina
# Processing Record 10 of Set 25 | milton
# Processing Record 11 of Set 25 | charters towers
# Processing Record 12 of Set 25 | daru
# Processing Record 13 of Set 25 | surgut
# Processing Record 14 of Set 25 | sur
# Processing Record 15 of Set 25 | bathsheba
# Processing Record 16 of Set 25 | isernia
# Processing Record 17 of Set 25 | culpeper
# Processing Record 18 of Set 25 | silanga
# Processing Record 19 of Set 25 | fort nelson
# Processing Record 20 of Set 25 | kadykchan
# City not found. Skipping...
# Processing Record 21 of Set 25 | kahului
# Processing Record 22 of Set 25 | ust-barguzin
# Processing Record 23 of Set 25 | tibiao
# Processing Record 24 of Set 25 | huanren
# Processing Record 25 of Set 25 | yefira
# City not found. Skipping...
# Processing Record 26 of Set 25 | petersburg
# Processing Record 27 of Set 25 | yumen
# Processing Record 28 of Set 25 | hinche
# Processing Record 29 of Set 25 | balkhash
# Processing Record 30 of Set 25 | bolcske
# Processing Record 31 of Set 25 | araguaina
# Processing Record 32 of Set 25 | columbus
# Processing Record 33 of Set 25 | zlitan
# Processing Record 34 of Set 25 | am timan
# Processing Record 35 of Set 25 | rio de jesus
# Processing Record 36 of Set 25 | sinjar
# Processing Record 37 of Set 25 | manicore
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Mandera      KE   3.94   41.87     78.08        67          36
# 1             Nome      US  64.50 -165.41     68.00        63           1
# 2            Vaini      TO -21.20 -175.20     73.40        73          75
# 3     Punta Arenas      CL -53.15  -70.92     33.80        84          72
# 4           Maceio      BR  -9.67  -35.74     73.40        88          75
# 5  Arraial Do Cabo      BR -22.97  -42.03     72.99        78          69
# 6   Novobirilyussy      RU  56.95   90.67     60.57        77           0
# 7            Sinop      TR  41.77   34.87     62.40        57           0
# 8            Kribi      CM   2.95    9.92     75.16        91          70
# 9       Codrington      AU -38.27  141.97     51.28        84           1
#
#    Wind Speed      Current Description  Rain (inches)  Snow (inches)
# 0       19.69         scattered clouds           0.00           0.00
# 1       12.75                clear sky           0.00           0.00
# 2       17.22  light intensity drizzle           0.00           0.00
# 3        8.05               light snow           0.00           0.13
# 4        1.12            broken clouds           0.00           0.00
# 5       15.68            broken clouds           0.00           0.00
# 6        2.57                clear sky           0.00           0.00
# 7        4.47                clear sky           0.00           0.00
# 8        6.31               light rain           0.21           0.00
# 9        3.47                clear sky           0.00           0.00

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="")
